# %%
#Module file for extracting data from APIs
import requests
import json
import os
import datetime

#Weather API

def get_weather(coor={'lat': 33.4936, "lon" : 117.1484}):
        keys = 'cd29c6e3a218049e216c1b1fb8be334a'
        r = requests.get(f'http://api.openweathermap.org/data/2.5/forecast?lat=33.4936&lon=-117.1484&appid={keys}')
        data = r.json()

        daily_forcast = {
            'city' : data['city']['name'],
            'country' : data['city']['country'],
            'periods' : list()
        }    

        for period in data['list'][0:9]:
            daily_forcast['periods'].append({'timestamp': datetime.datetime.fromtimestamp(period['dt']),
                                              'temp' : round(period['main']['temp']),
                                              'description' : period['weather'][0]['description'].title(),
                                              'icon' : f'http://openweathermap.org/img/wn/{period["weather"][0]["icon"]}.png'})
        
        #return daily_forcast
        return data
get_weather()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1647054000,
#    'main': {'temp': 291.27,
#     'feels_like': 289.66,
#     'temp_min': 285.29,
#     'temp_max': 291.27,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 988,
#     'humidity': 20,
#     'temp_kf': 5.98},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.36, 'deg': 180, 'gust': 1.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-03-12 03:00:00'},
#   {'dt': 1647064800,
#    'main': {'temp': 287.03,
#     'feels_like': 285.07,
#     'temp_min': 283.41,
#     'temp_max': 287.03,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 988,
#     'humidity': 23,
#     'temp_kf': 3.62},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
# ...

# %%
#today = datetime.date.today()

yesterday = datetime.date.today() - datetime.timedelta(days=1)
print(yesterday)
# Out:
# 2022-03-10

# %%
def get_scores():
        date = datetime.date.today() - datetime.timedelta(days=1)
        querystring = {"date": f"{date}"}
        headers = {
           'x-rapidapi-host': "api-nba-v1.p.rapidapi.com",
           'x-rapidapi-key': "eb401d6c00msh699af860cb64325p16eb7fjsnafd5c623b6ad"}
        
        r = requests.get("https://api-nba-v1.p.rapidapi.com/games",headers=headers, params=querystring)
        data = r.json()
        print(json.dumps(data, indent=4, separators=(',', ': '), sort_keys=True))
        
get_scores()
# Out:
# {
#     "errors": [],
#     "get": "games/",
#     "parameters": {
#         "date": "2022-03-10"
#     },
#     "response": [
#         {
#             "arena": {
#                 "city": "Charlotte",
#                 "country": "USA",
#                 "name": "Spectrum Center",
#                 "state": "NC"
#             },
#             "date": {
#                 "duration": "2:07",
#                 "end": "2022-03-10T02:18:00.000Z",
#                 "start": "2022-03-10T00:00:00.000Z"
#             },
#             "id": 10546,
#             "leadChanges": 9,
#             "league": "standard",
#             "nugget": null,
#             "officials": [
#                 "Marc Davis",
#                 "Tyler Ford",
#                 "Aaron Smith"
#             ],
#             "periods": {
#                 "current": 4,
#                 "endOfPeriod": false,
#                 "total": 4
#             },
#             "scores": {
#                 "home": {
# ...

# %%
def get_scores():
        date = datetime.date.today() - datetime.timedelta(days=1)
        querystring = {"date": f"{date}"}
        headers = {
           'x-rapidapi-host': "api-nba-v1.p.rapidapi.com",
           'x-rapidapi-key': "eb401d6c00msh699af860cb64325p16eb7fjsnafd5c623b6ad"}
        
        r = requests.get("https://api-nba-v1.p.rapidapi.com/games",headers=headers, params=querystring)

        data = r.json()

        last_night_scores = {
            'Home Team' : data["response"][0]['teams']['home']['name'],
            'Home Score' : data['response'][0]['scores']['home']['points'],
            'Away Team' : data["response"][0]['teams']['visitors']['name'],
            'Away Score' : data['response'][0]['scores']['home']['points'],
        }

        print(last_night_scores)

# %%
get_scores()
# Out:
# {'Home Team': 'Charlotte Hornets', 'Home Score': 101, 'Away Team': 'Boston Celtics', 'Away Score': 101}

# %%
def get_scores():
        date = datetime.date.today() - datetime.timedelta(days=1)
        querystring = {"date": f"{date}"}
        headers = {
           'x-rapidapi-host': "api-nba-v1.p.rapidapi.com",
           'x-rapidapi-key': "eb401d6c00msh699af860cb64325p16eb7fjsnafd5c623b6ad"}
        
        r = requests.get("https://api-nba-v1.p.rapidapi.com/games",headers=headers, params=querystring)

        data = r.json()
        scores = list()
        
        for i in range(len(data['response'])):
            scores.append({
            'Home Team' : data["response"][i]['teams']['home']['name'],
            'Home Score' : data['response'][i]['scores']['home']['points'],
            'Away Team' : data["response"][i]['teams']['visitors']['name'],
            'Away Score' : data['response'][i]['scores']['home']['points'],
        })

        print(scores)

# %%
get_scores()
# Out:
# [{'Home Team': 'Charlotte Hornets', 'Home Score': 101, 'Away Team': 'Boston Celtics', 'Away Score': 101}, {'Home Team': 'Detroit Pistons', 'Home Score': 108, 'Away Team': 'Chicago Bulls', 'Away Score': 108}, {'Home Team': 'Miami Heat', 'Home Score': 90, 'Away Team': 'Phoenix Suns', 'Away Score': 90}, {'Home Team': 'Milwaukee Bucks', 'Home Score': 124, 'Away Team': 'Atlanta Hawks', 'Away Score': 124}, {'Home Team': 'Houston Rockets', 'Home Score': 139, 'Away Team': 'Los Angeles Lakers', 'Away Score': 139}, {'Home Team': 'Minnesota Timberwolves', 'Home Score': 132, 'Away Team': 'Oklahoma City Thunder', 'Away Score': 132}, {'Home Team': 'New Orleans Pelicans', 'Home Score': 102, 'Away Team': 'Orlando Magic', 'Away Score': 102}, {'Home Team': 'Dallas Mavericks', 'Home Score': 77, 'Away Team': 'New York Knicks', 'Away Score': 77}, {'Home Team': 'San Antonio Spurs', 'Home Score': 104, 'Away Team': 'Toronto Raptors', 'Away Score': 104}, {'Home Team': 'Utah Jazz', 'Home Score': 123, 'Away Te
# ...

# %%
from newsapi import NewsApiClient
def get_headlines():
    try:
        r = requests.get('https://newsapi.org/v2/top-headlines?country=us&apiKey=de5151d82dfa46008dad2a320afefc4f')
        data = r.json()
        headlines = list()

        for i in range(len(data['articles'][0:9])):
            headlines.append({
                "Source" : data['articles'][i]['source']['name'],
                "Headline" : data['articles'][i]['title'],
                'Description' : data['articles'][i]['description'],
                'Link' : data['articles'][i]['url']
            })

        return headlines
    
    except Exception as e:
        print(e)

# %%
get_headlines()
# Out:
# [{'Source': 'New York Times',
#   'Headline': 'The Latest Ukraine-Russia War News: Live Updates and Video - The New York Times',
#   'Description': 'The low rumble of heavy artillery fire echoed across Kyiv on Friday as Russian forces renewed their ground offensive and widened their bombardment of Ukraine.',
#   'Link': 'https://www.nytimes.com/live/2022/03/11/world/ukraine-russia-news'},
#  {'Source': 'The Washington Post',
#   'Headline': 'United Nations Security Council to meet over Russian claim of biolabs in Ukraine - The Washington Post',
#   'Description': "The claim was vehemently denied by the United States and Ukraine, with both warning the Russian disinformation campaign could be a prelude to Russia's use of chemical weapons.",
#   'Link': 'https://www.washingtonpost.com/world/2022/03/11/un-council-ukraine-russia-chemical-weapons-zelensky/'},
#  {'Source': 'CNBC',
# ...

# %%
def word_of_day():
    try:
        querystring = {"random":"true"}

        headers = {
            'x-rapidapi-host': "wordsapiv1.p.rapidapi.com",
            'x-rapidapi-key': "eb401d6c00msh699af860cb64325p16eb7fjsnafd5c623b6ad"
            }
        
        r = requests.get('https://wordsapiv1.p.rapidapi.com/words/', headers=headers,params=querystring)
        data = r.json()
        word = data['word']
        r2 = requests.get(f"https://wordsapiv1.p.rapidapi.com/words/{word}/definitions", headers=headers)

        definition = r2.text
        print(definition)

    except Exception as e:
        print(e)

# %%
word_of_day()
# Out:
# {"word":"stockade","definitions":[{"definition":"a penal camp where political prisoners or prisoners of war are confined (usually under harsh conditions)","partOfSpeech":"noun"},{"definition":"fortification consisting of a fence made of a line of stout posts set firmly for defense","partOfSpeech":"noun"},{"definition":"surround with a stockade in order to fortify","partOfSpeech":"verb"}]}

# %%
def get_word_of_day():
    try:
        querystring = {"random":"true"}

        headers = {
            'x-rapidapi-host': "wordsapiv1.p.rapidapi.com",
            'x-rapidapi-key': "eb401d6c00msh699af860cb64325p16eb7fjsnafd5c623b6ad"
            }
        
        r = requests.get('https://wordsapiv1.p.rapidapi.com/words/', headers=headers,params=querystring)
        data = r.json()
        word = data['word']
        r2 = requests.get(f"https://wordsapiv1.p.rapidapi.com/words/{word}/definitions", headers=headers)

        definition = r2.json()
        print(definition)

    except Exception as e:
        print(e)

# %%
get_word_of_day()
# Out:
# {'word': 'royal brace', 'definitions': [{'definition': 'a brace to secure the royal mast', 'partOfSpeech': 'noun'}]}
